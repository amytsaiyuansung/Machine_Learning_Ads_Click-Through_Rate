# %%
import pandas as pd
import numpy as np

# %%
Train = pd.read_csv('Train-011.csv', header = None)

# %%
Train.columns = ['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
       'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
       'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
       'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21']

# %%
for i in Train.columns:
    print(Train.groupby(i).click.sum()/Train.groupby(i).click.count())
# Out:
# id
# 25747442208961          0.0
# 30135266270276          0.0
# 46888036639068          0.0
# 52139395479640          0.0
# 67013021853780          0.0
# 76197164537231          0.0
# 120602009352535         0.0
# 123414072479525         0.0
# 138166778568855         0.0
# 145224608455238         0.0
# 167230255683229         1.0
# 192152711298240         1.0
# 193010956677044         0.0
# 208087952402549         0.0
# 230483014577220         1.0
# 277227587331805         0.0
# 278342971124267         0.0
# 284345801863037         0.0
# 286416390642094         0.0
# 302322739850524         0.0
# 322577162745620         0.0
# 326553592344913         0.0
# 326610368753158         0.0
# 337266619635770         0.0
# 352063758694285         0.0
# 372308244876603         1.0
# 406895918920555         0.0
# 436468716187517         1.0
# 452707711473091         0.0
# 470104614708450         1.0
#                        ...
# 18446217586374213864    0.0
# 18446239593392751241    0.0
# ...

# %%
for i in Train.columns:
    print(i, Train[i].nunique())
# Out:
# id 1000000
# click 2
# hour 216
# C1 7
# banner_pos 7
# site_id 2657
# site_domain 2893
# site_category 21
# app_id 3167
# app_domain 203
# app_category 27
# device_id 151687
# device_ip 546575
# device_model 5165
# device_type 5
# device_conn_type 4
# C14 2108
# C15 8
# C16 9
# C17 394
# C18 4
# C19 65
# C20 165
# C21 55

# %%
Train.drop(['device_id', 'device_ip'], axis = 1, inplace = True)

# %%
for i in Train.columns:
    print(i, Train[i].nunique())
# Out:
# id 1000000
# click 2
# hour 216
# C1 7
# banner_pos 7
# site_id 2657
# site_domain 2893
# site_category 21
# app_id 3167
# app_domain 203
# app_category 27
# device_model 5165
# device_type 5
# device_conn_type 4
# C14 2108
# C15 8
# C16 9
# C17 394
# C18 4
# C19 65
# C20 165
# C21 55

# %%
for i in np.r_[5,6,8,9,11,14,17,20]:
    print(Train[Train.columns[i]].value_counts())
# Out:
# 85f751fd    349640
# 1fbe01fe    162604
# e151e245     65559
# d9750ee7     24794
# 5b08c53b     22549
# 856e6d3f     20171
# 5b4d2eda     19177
# a7853007     12640
# b7e9786d      9123
# 5bcf81a2      8873
# 6399eda6      8741
# 5ee41ff2      8680
# 6256f5b4      8074
# 17caea14      7050
# 0a742914      7010
# 57ef2c87      6821
# 83a0ad1a      6714
# 57fe1b20      6642
# e4d8dd7b      6441
# e8f79e60      6416
# d6137915      5703
# 12fb4121      5234
# 6c5b482c      4762
# 9a977531      4566
# 93eaba74      4521
# e5c60a05      4505
# 5114c672      4464
# bb4524e7      4438
# e3c09f3a      4150
# ce3307ec      3870
#              ...
# 46a708ff         1
# 2b9d088f         1
# 8fd5b173         1
# c0914730         1
# d60447aa         1
# 23d265e0         1
# 892553e7         1
# 495a2758         1
# a18ebdf5         1
# b6bd4c1e         1
# d9e93013         1
# 24e04145         1
# 3491297b         1
# 4357c249         1
# c6cc45df         1
# fe1ffb33         1
# ...

# %%
for i in np.r_[5,6,8,9,11,14,17,20]:
    print(Train.groupby(Train.columns[i]).click.sum()/Train.groupby(Train.columns[i]).click.count())
# Out:
# site_id
# 00255fb4    0.000000
# 003cf93d    0.000000
# 006ab81e    0.200000
# 009f04fc    0.000000
# 00b73968    0.666667
# 00f5367d    0.000000
# 00f648b7    0.281250
# 00f7c6fc    0.000000
# 0114bb39    0.000000
# 011e5414    0.210526
# 01270328    0.173913
# 0129a661    0.250000
# 013e516e    0.000000
# 014428c1    0.115385
# 015cc1dc    0.000000
# 019de78a    0.000000
# 01da43f6    0.333333
# 021ba5c7    0.000000
# 021cd138    0.387283
# 02296256    0.200000
# 0234a6fa    0.576923
# 023f3644    0.012739
# 02546dd5    0.000000
# 0273c5ad    0.077922
# 029faab5    0.500000
# 02a3c438    0.000000
# 02a66025    0.136364
# 02d41cd4    0.000000
# 02d5151c    0.025316
# 02d5ce7e    0.333333
#               ...
# fe96dcee    0.000000
# fec6e632    0.128282
# fed1a009    0.000000
# fee8da23    0.000000
# fefe6fb9    0.205479
# ff06bce4    0.000000
# ff0784fb    0.384615
# ff108d09    0.000000
# ff18c3d1    0.345196
# ff1b88b6    0.000000
# ff1bcc6f    0.175000
# ff255427    0.500000
# ...

# %% [markdown]
# # site_id

# %%
appearance = pd.DataFrame(Train[Train.columns[5]].value_counts())

effect = pd.DataFrame(Train.groupby(Train.columns[5]).click.sum()/Train.groupby(Train.columns[5]).click.count())

pd.concat([appearance, effect], axis = 1).sort_values(['site_id'], ascending = False)

# %% [markdown]
# # site_domain

# %%
appearance = pd.DataFrame(Train[Train.columns[6]].value_counts())

effect = pd.DataFrame(Train.groupby(Train.columns[6]).click.sum()/Train.groupby(Train.columns[6]).click.count())

pd.concat([appearance, effect], axis = 1).sort_values('site_domain', ascending = False)
# Out:
# C:\Users\jczsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#           site_domain     click
# c4e18dd6       362918  0.120829
# f3845767       162604  0.205124
# 7e091613        84124  0.255135
# 7687a86e        31832  0.460543
# 98572c79        25704  0.271047
# 16a36ef3        21285  0.140991
# 58a89a43        20171  0.043577
# 9d54950b         9882  0.110909
# b12b9f85         9282  0.072290
# 17d996e6         8801  0.324849
# 968765cd         8741  0.109827
# 28f93029         8074  0.176121
# d262cf1e         7552  0.020922
# 0dde25ec         7050  0.244113
# 510bd839         7010  0.274322
# bd6d812f         6821  0.125788
# 5c9ae867         6714  0.087578
# 5b626596         6664  0.237845
# ...

# %% [markdown]
# # app_id

# %%
appearance = pd.DataFrame(Train[Train.columns[8]].value_counts())

effect = pd.DataFrame(Train.groupby(Train.columns[8]).click.sum()/Train.groupby(Train.columns[8]).click.count())

pd.concat([appearance, effect], axis = 1).sort_values(['app_id'], ascending = False)
# Out:
# C:\Users\jczsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#           app_id     click
# ecad2386  650360  0.197477
# 92f5800b   42986  0.018913
# e2fcccd2   27662  0.197563
# febd1138   18808  0.049607
# 7358e05e   16074  0.191987
# a5184c22   12498  0.245239
# 9c13b419   11222  0.309838
# 54c5d545   10300  0.123398
# 03528b27    8251  0.140468
# e9739828    7429  0.028537
# f0d41ff1    7199  0.060286
# e2a1ca37    7018  0.142918
# 03a08c3f    5958  0.053038
# 51cedd4e    5791  0.051114
# 66f5e02e    5667  0.221987
# 98fed791    5578  0.140731
# 73206397    5315  0.028975
# 685d1c4c    5146  0.068208
# e96773f0    4815  0.071859
# f53417e1    4536  0.076940
# d36838b1    4483  0.070712
# ...

# %% [markdown]
# # app_domain

# %%
appearance = pd.DataFrame(Train[Train.columns[9]].value_counts())

effect = pd.DataFrame(Train.groupby(Train.columns[9]).click.sum()/Train.groupby(Train.columns[9]).click.count())

pd.concat([appearance, effect], axis = 1).sort_values(['app_domain'], ascending = False)
# Out:
# C:\Users\jczsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#           app_domain     click
# 7801e8d9      686856  0.193748
# 2347f47a      116196  0.134161
# ae637522       51417  0.023864
# 5c5a694b       27666  0.197535
# 82e27996       18808  0.049607
# d9b5648e       18335  0.113608
# b9528b13       16712  0.186213
# b8d325c3       13693  0.228876
# 0e8616ad        9141  0.074062
# df32afa9        7591  0.028586
# aefc06bd        7385  0.070955
# 33da2e74        6930  0.110245
# 6f7ca2ba        5668  0.221948
# 5b9c592b        2501  0.063175
# 885c7f3f        1811  0.166207
# 5c620f04        1496  0.030080
# 45a51db4        1290  0.198450
# b5f3b24a        1125  0.036444
# ...

# %% [markdown]
# # device_model

# %%
appearance = pd.DataFrame(Train[Train.columns[11]].value_counts())

effect = pd.DataFrame(Train.groupby(Train.columns[11]).click.sum()/Train.groupby(Train.columns[11]).click.count())

pd.concat([appearance, effect], axis = 1).sort_values(['device_model'], ascending = False)
# Out:
# C:\Users\jczsh\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#           device_model     click
# 8a4875bd         60570  0.137824
# 1f0bc64f         34788  0.226084
# d787e91b         34542  0.227694
# 76dc4769         18930  0.188484
# be6db1d7         17965  0.185583
# a0f5f879         16204  0.162614
# 4ea23a13         16078  0.214330
# 7abbbd5c         15643  0.173880
# ecb851b2         15210  0.179816
# d4897fef         12167  0.169557
# 5096d134         11580  0.172539
# e1eae715         11495  0.016616
# 711ee120         11225  0.209265
# 1ccc7835         10241  0.180061
# 981edffc         10014  0.017476
# 0bcabeaf          9813  0.020381
# c6263d8a          9766  0.258960
# ...

# %% [markdown]
# # C14

# %%
appearance = pd.DataFrame(Train[Train.columns[14]].value_counts())

effect = pd.DataFrame(Train.groupby(Train.columns[14]).click.sum()/Train.groupby(Train.columns[14]).click.count())

pd.concat([appearance, effect], axis = 1).sort_values(['C14'], ascending = False)
# Out:
#          C14     click
# 4687   25390  0.251438
# 21611  22648  0.060535
# 21191  21216  0.020645
# 21189  21215  0.019137
# 19772  18810  0.110101
# 19771  18503  0.116630
# 16208  17571  0.116954
# 20108  15205  0.247747
# 19950  13894  0.122859
# 15705  13734  0.207441
# 15701  13530  0.203178
# 15707  13351  0.195416
# 15708  13317  0.191710
# 15704  13299  0.202722
# 15703  13298  0.191232
# 15699  13290  0.202558
# 15702  12894  0.157050
# 15706  12731  0.153012
# 16615  12076  0.195595
# 8330   12049  0.146568
# 21768  10576  0.106657
# 21767  10315  0.103248
# 19251   9391  0.076669
# 17239   8751  0.181579
# 21790   7776  0.091692
# 6563    7511  0.239116
# 17653   7323  0.388365
# 17654   7251  0.398979
# 20633   7100  0.267887
# 16920   7088  0.267635
# ...      ...       ...
# 19745      1  0.000000
# 23126      1  0.000000
# 23127      1  0.000000
# 23131      1  1.000000
# 21707      1  0.000000
# 21607      1  0.000000
# 21602      1  0.000000
# 21600      1  0.000000
# ...

# %% [markdown]
# # C17

# %%
appearance = pd.DataFrame(Train[Train.columns[17]].value_counts())

effect = pd.DataFrame(Train.groupby(Train.columns[17]).click.sum()/Train.groupby(Train.columns[17]).click.count())

pd.concat([appearance, effect], axis = 1).sort_values(['C17'], ascending = False)
# Out:
#          C17     click
# 1722  119867  0.189685
# 2424   42431  0.019891
# 2227   37672  0.113320
# 1800   31550  0.119493
# 423    25390  0.251438
# 2502   23813  0.197413
# 2480   22973  0.060985
# 2506   22359  0.102151
# 2528   21941  0.135363
# 2374   19891  0.251772
# 1872   17882  0.301644
# 2545   15684  0.217164
# 1863   15657  0.168168
# 2299   15205  0.247747
# 2526   15016  0.120139
# 1994   14574  0.393646
# 2333   14144  0.165653
# 2665   13289  0.073444
# 1993   12522  0.362242
# 761    12139  0.146223
# 2507   12106  0.085247
# 1873   12042  0.142916
# 2566   10021  0.111167
# 2201    9391  0.076669
# 2513    8905  0.118697
# 1973    8751  0.181579
# 2676    8286  0.160753
# 2340    8214  0.114682
# 2036    8044  0.064272
# 572     7511  0.239116
# ...      ...       ...
# 2686      16  0.250000
# 873       15  0.000000
# 2270      14  0.142857
# 2436      14  0.071429
# 2525      13  0.153846
# 2703      13  0.153846
# 2670      12  0.166667
# 2593      12  0.083333
# ...

# %% [markdown]
# # C20

# %%
appearance = pd.DataFrame(Train[Train.columns[20]].value_counts())

effect = pd.DataFrame(Train.groupby(Train.columns[20]).click.sum()/Train.groupby(Train.columns[20]).click.count())

pd.concat([appearance, effect], axis = 1).sort_values(['C20'], ascending = False)
# Out:
#             C20     click
# -1       464202  0.193028
#  100084   61936  0.212429
#  100111   44772  0.089721
#  100148   43880  0.233022
#  100077   39736  0.175106
#  100075   38715  0.160739
#  100081   32924  0.192777
#  100156   27410  0.093470
#  100083   27051  0.191231
#  100193   19623  0.020792
#  100074   14709  0.166565
#  100079   14349  0.143703
#  100176   13035  0.128270
#  100189   12888  0.025528
#  100076   11051  0.149851
#  100192    6293  0.031940
#  100190    6210  0.023510
#  100191    6059  0.083017
#  100188    5436  0.130059
#  100031    5094  0.185316
#  100013    4272  0.139513
#  100155    4139  0.156318
#  100181    3754  0.117208
#  100194    3640  0.089560
#  100000    3221  0.088792
#  100003    3074  0.044893
#  100119    2970  0.169024
#  100105    2924  0.128591
#  100182    2874  0.127349
#  100173    2507  0.273235
# ...         ...       ...
#  100152      59  0.203390
#  100073      55  0.254545
#  100224      55  0.327273
# ...
